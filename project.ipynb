# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/gsearch_jobs.csv")

# %%
df
# Out:
#        Unnamed: 0  index                                              title  \
# 0               0      0  Data Analyst - Remote! ($64663.00 - $96994.00 ...
# 1               1      1                             Data Analyst - 7010605
# 2               2      2                          SQL Data Analyst (Remote)
# 3               3      3                                       Data Analyst
# 4               4      4                       Senior Data Analyst (Remote)
# ...           ...    ...                                                ...
# 48902       48902    591                     Marketing Data & BI Analyst II
# 48903       48903    592                                  Lead-Data Analyst
# 48904       48904    593                                  Lead-Data Analyst
# 48905       48905    594                                  Lead-Data Analyst
# 48906       48906    595  Institutional Credit Management - Lending Data...
#
#             company_name                 location  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'title', 'company_name', 'location', 'via',
#        'description', 'extensions', 'job_id', 'thumbnail', 'posted_at',
#        'schedule_type', 'work_from_home', 'salary', 'search_term', 'date_time',
#        'search_location', 'commute_time', 'salary_pay', 'salary_rate',
#        'salary_avg', 'salary_min', 'salary_max', 'salary_hourly',
#        'salary_yearly', 'salary_standardized', 'description_tokens'],
#       dtype='object')

# %%
df=df.drop(['Unnamed: 0','index',"job_id",'thumbnail'],axis = 1)

# %%
print(df.extensions.iloc[3])

print(df.salary_standardized.iloc[456])
# Out:
# ['13 hours ago', 'Full-time', 'Health insurance']
# 65520.0

# %%
df.isna().sum()
# Out:
# Unnamed: 0                 0
# index                      0
# title                      0
# company_name               0
# location                  36
# via                        9
# description                0
# extensions                 0
# job_id                     0
# thumbnail              18759
# posted_at                  0
# schedule_type            184
# work_from_home         25655
# salary                 40518
# search_term                0
# date_time                  0
# search_location            0
# commute_time           48907
# salary_pay             40518
# salary_rate            40518
# salary_avg             40518
# salary_min             40984
# salary_max             40984
# salary_hourly          43653
# salary_yearly          45800
# salary_standardized    40518
# description_tokens         0
# dtype: int64
